# %%
# !pip3 install swig
# Out:
# Collecting swig
#   Downloading swig-4.1.1-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 23.1 MB/s eta 0:00:00
# Installing collected packages: swig
# Successfully installed swig-4.1.1

# %%
# !pip3 install gym[box2d]
# Out:
# Requirement already satisfied: gym[box2d] in /usr/local/lib/python3.10/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym[box2d]) (1.22.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym[box2d]) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym[box2d]) (0.0.8)
# Collecting box2d-py==2.3.5 (from gym[box2d])
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 7.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pygame==2.1.0 (from gym[box2d])
#   Downloading pygame-2.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 83.2 MB/s eta 0:00:00
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.10/dist-packages (from gym[box2d]) (4.1.1)
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp310-cp310-linux_x86_64.whl size=2373081 sha256=92ce5e16a2d7ddd581fdb4c4ee39232aeeaae6a14039e9de46cc22eeff371faa
#   Stored in directory: /root/.cache/pip/wheels/db/8f/6a/eaaadf056fba10a98d986f6dce954e6201ba3126926fc5ad9e
# Successfully built box2d-py
# Installing collected packages: box2d-py, pygame
#   Attempting uninstall: pygame
#     Found existing installation: pygame 2.5.0
#     Uninstalling pygame-2.5.0:
#       Successfully uninstalled pygame-2.5.0
# Successfully installed box2d-py-2.3.5 pygame-2.1.0

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Sun Jul 30 13:54:52 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    43W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip3 install pyglet
# Out:
# Collecting pyglet
#   Downloading pyglet-2.0.9-py3-none-any.whl (854 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 854.7/854.7 kB 15.1 MB/s eta 0:00:00
# Installing collected packages: pyglet
# Successfully installed pyglet-2.0.9

# %%
# !pip3 install stable_baselines3
# Out:
# Collecting stable_baselines3
#   Downloading stable_baselines3-2.0.0-py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.4/178.4 kB 3.3 MB/s eta 0:00:00
# Collecting gymnasium==0.28.1 (from stable_baselines3)
#   Downloading gymnasium-0.28.1-py3-none-any.whl (925 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 925.5/925.5 kB 50.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (1.22.4)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.0.1+cu118)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable_baselines3) (3.7.1)
# Collecting jax-jumpy>=1.0.0 (from gymnasium==0.28.1->stable_baselines3)
#   Downloading jax_jumpy-1.0.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium==0.28.1->stable_baselines3) (4.7.1)
# Collecting farama-notifications>=0.0.1 (from gymnasium==0.28.1->stable_baselines3)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable_baselines3) (3.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable_baselines3) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable_baselines3) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable_baselines3) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable_baselines3) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11->stable_baselines3) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11->stable_baselines3) (16.0.6)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable_baselines3) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11->stable_baselines3) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11->stable_baselines3) (1.3.0)
# Installing collected packages: farama-notifications, jax-jumpy, gymnasium, stable_baselines3
# Successfully installed farama-notifications-0.0.4 gymnasium-0.28.1 jax-jumpy-1.0.0 stable_baselines3-2.0.0

# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor
import os
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
env =gym.make('CarRacing-v2')
env = DummyVecEnv([lambda: env])

# %%
log_path = os.path.join('logs')

# %%
model = PPO('CnnPolicy',env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=500000)
# Out:
# Logging to logs/PPO_2
# -----------------------------
# | time/              |      |
# |    fps             | 76   |
# |    iterations      | 1    |
# |    time_elapsed    | 26   |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 2           |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007636608 |
# |    clip_fraction        | 0.0816      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.000204    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0862      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00882    |
# |    std                  | 0.99        |
# |    value_loss           | 0.515       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 71          |
# |    iterations           | 3           |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.007598822 |
# |    clip_fraction        | 0.0601      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.22       |
# |    explained_variance   | 0.129       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0773      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00595    |
# |    std                  | 0.985       |
# |    value_loss           | 0.52        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 70         |
# |    iterations           | 4          |
# |    time_elapsed         | 115        |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00671558 |
# |    clip_fraction        | 0.106      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.21      |
# |    explained_variance   | 0.0947     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.159      |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.00778   |
# |    std                  | 0.984      |
# |    value_loss           | 0.407      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 70         |
# |    iterations           | 5          |
# |    time_elapsed         | 145        |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.00942529 |
# |    clip_fraction        | 0.112      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.2       |
# |    explained_variance   | 0.329      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.096      |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0117    |
# |    std                  | 0.977      |
# |    value_loss           | 0.414      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 6           |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011576748 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 0.0127      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0556      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0155     |
# |    std                  | 0.967       |
# |    value_loss           | 0.339       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 7           |
# |    time_elapsed         | 204         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.014331119 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.13       |
# |    explained_variance   | 0.304       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.104       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0185     |
# |    std                  | 0.955       |
# |    value_loss           | 0.342       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 8           |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.017239664 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.09       |
# |    explained_variance   | 0.0547      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.067       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0203     |
# |    std                  | 0.943       |
# |    value_loss           | 0.313       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 9           |
# |    time_elapsed         | 263         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.018937198 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.05       |
# |    explained_variance   | 0.155       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0594      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.024      |
# |    std                  | 0.927       |
# |    value_loss           | 0.281       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 10          |
# |    time_elapsed         | 292         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.015073426 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.02       |
# |    explained_variance   | 0.344       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0144      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0186     |
# |    std                  | 0.918       |
# |    value_loss           | 0.297       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 11         |
# |    time_elapsed         | 322        |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.01684786 |
# |    clip_fraction        | 0.172      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.98      |
# |    explained_variance   | 0.0309     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0742     |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0189    |
# |    std                  | 0.907      |
# |    value_loss           | 0.322      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 12          |
# |    time_elapsed         | 351         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.022015782 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.95       |
# |    explained_variance   | 0.039       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0347     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0244     |
# |    std                  | 0.9         |
# |    value_loss           | 0.268       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 13          |
# |    time_elapsed         | 380         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.015364301 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.92       |
# |    explained_variance   | 0.616       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0201      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0164     |
# |    std                  | 0.89        |
# |    value_loss           | 0.28        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 14          |
# |    time_elapsed         | 409         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.016717695 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.89       |
# |    explained_variance   | 0.737       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0214      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0175     |
# |    std                  | 0.882       |
# |    value_loss           | 0.191       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 15          |
# |    time_elapsed         | 439         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.021865677 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.86       |
# |    explained_variance   | 0.808       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00575     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0174     |
# |    std                  | 0.872       |
# |    value_loss           | 0.133       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 16          |
# |    time_elapsed         | 468         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.024896763 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.82       |
# |    explained_variance   | 0.872       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0125      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0265     |
# |    std                  | 0.86        |
# |    value_loss           | 0.168       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 17          |
# |    time_elapsed         | 497         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.017407238 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.79       |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0127     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0154     |
# |    std                  | 0.85        |
# |    value_loss           | 0.134       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 18         |
# |    time_elapsed         | 526        |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.02001486 |
# |    clip_fraction        | 0.218      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.76      |
# |    explained_variance   | 0.926      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0266    |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0189    |
# |    std                  | 0.844      |
# |    value_loss           | 0.125      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 19          |
# |    time_elapsed         | 556         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.028694965 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.73       |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0559     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0257     |
# |    std                  | 0.837       |
# |    value_loss           | 0.0935      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 20          |
# |    time_elapsed         | 585         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.021194875 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.7        |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00551    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0207     |
# |    std                  | 0.824       |
# |    value_loss           | 0.14        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 21          |
# |    time_elapsed         | 614         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.020555437 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.67       |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0216     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0209     |
# |    std                  | 0.82        |
# |    value_loss           | 0.107       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 22          |
# |    time_elapsed         | 643         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.026915025 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.65       |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0306     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0286     |
# |    std                  | 0.813       |
# |    value_loss           | 0.0708      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 70         |
# |    iterations           | 23         |
# |    time_elapsed         | 672        |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.02631139 |
# |    clip_fraction        | 0.224      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.6       |
# |    explained_variance   | 0.887      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0177     |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0213    |
# |    std                  | 0.797      |
# |    value_loss           | 0.156      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 24          |
# |    time_elapsed         | 701         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.031355985 |
# |    clip_fraction        | 0.278       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.56       |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00585    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0338     |
# |    std                  | 0.789       |
# |    value_loss           | 0.257       |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 70        |
# |    iterations           | 25        |
# |    time_elapsed         | 730       |
# |    total_timesteps      | 51200     |
# | train/                  |           |
# |    approx_kl            | 0.0382517 |
# |    clip_fraction        | 0.319     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.52     |
# |    explained_variance   | 0.861     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0663    |
# |    n_updates            | 240       |
# |    policy_gradient_loss | -0.0383   |
# |    std                  | 0.776     |
# |    value_loss           | 0.431     |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 70         |
# |    iterations           | 26         |
# |    time_elapsed         | 759        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.03476911 |
# |    clip_fraction        | 0.331      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.47      |
# |    explained_variance   | 0.91       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.104      |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0379    |
# |    std                  | 0.767      |
# |    value_loss           | 0.424      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 70          |
# |    iterations           | 27          |
# |    time_elapsed         | 789         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.042290404 |
# |    clip_fraction        | 0.3         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.46       |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00942    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0322     |
# |    std                  | 0.767       |
# |    value_loss           | 0.272       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 70         |
# |    iterations           | 28         |
# |    time_elapsed         | 818        |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.04219445 |
# |    clip_fraction        | 0.32       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.44      |
# |    explained_variance   | 0.932      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0313     |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0354    |
# |    std                  | 0.76       |
# |    value_loss           | 0.446      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 29         |
# |    time_elapsed         | 848        |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.03334513 |
# |    clip_fraction        | 0.301      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.41      |
# |    explained_variance   | 0.869      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.111      |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.0284    |
# |    std                  | 0.751      |
# |    value_loss           | 0.631      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 30         |
# |    time_elapsed         | 878        |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.05386903 |
# |    clip_fraction        | 0.343      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.38      |
# |    explained_variance   | 0.934      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00546   |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.0432    |
# |    std                  | 0.747      |
# |    value_loss           | 0.412      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 31         |
# |    time_elapsed         | 907        |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.04522501 |
# |    clip_fraction        | 0.333      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.36      |
# |    explained_variance   | 0.863      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.127      |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.0409    |
# |    std                  | 0.74       |
# |    value_loss           | 0.761      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 32          |
# |    time_elapsed         | 938         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.034388594 |
# |    clip_fraction        | 0.294       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.32       |
# |    explained_variance   | 0.495       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.175       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0337     |
# |    std                  | 0.732       |
# |    value_loss           | 1.06        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 33          |
# |    time_elapsed         | 968         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.050100338 |
# |    clip_fraction        | 0.351       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.28       |
# |    explained_variance   | 0.692       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0942      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0395     |
# |    std                  | 0.718       |
# |    value_loss           | 0.704       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 34          |
# |    time_elapsed         | 998         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.057155915 |
# |    clip_fraction        | 0.342       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.23       |
# |    explained_variance   | 0.731       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.33        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0376     |
# |    std                  | 0.711       |
# |    value_loss           | 0.985       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 35          |
# |    time_elapsed         | 1028        |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.045931395 |
# |    clip_fraction        | 0.32        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | 0.577       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.151       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0341     |
# |    std                  | 0.706       |
# |    value_loss           | 1.44        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 36         |
# |    time_elapsed         | 1058       |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.04805301 |
# |    clip_fraction        | 0.35       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.19      |
# |    explained_variance   | 0.453      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.465      |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.0217    |
# |    std                  | 0.704      |
# |    value_loss           | 2.49       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 37         |
# |    time_elapsed         | 1088       |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.06424783 |
# |    clip_fraction        | 0.378      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.17      |
# |    explained_variance   | 0.545      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.263      |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0249    |
# |    std                  | 0.699      |
# |    value_loss           | 1.58       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 38         |
# |    time_elapsed         | 1118       |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.05540862 |
# |    clip_fraction        | 0.397      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.14      |
# |    explained_variance   | 0.476      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.231      |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.00977   |
# |    std                  | 0.692      |
# |    value_loss           | 1.28       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 39          |
# |    time_elapsed         | 1148        |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.053340405 |
# |    clip_fraction        | 0.398       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.11       |
# |    explained_variance   | 0.681       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.274       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0106     |
# |    std                  | 0.686       |
# |    value_loss           | 1.57        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 40         |
# |    time_elapsed         | 1177       |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.04900203 |
# |    clip_fraction        | 0.404      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.1       |
# |    explained_variance   | 0.54       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.271      |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0134    |
# |    std                  | 0.685      |
# |    value_loss           | 3.52       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 41         |
# |    time_elapsed         | 1208       |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.06321785 |
# |    clip_fraction        | 0.464      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.09      |
# |    explained_variance   | 0.802      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.539      |
# |    n_updates            | 400        |
# |    policy_gradient_loss | 0.00852    |
# |    std                  | 0.683      |
# |    value_loss           | 5.63       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 42         |
# |    time_elapsed         | 1238       |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.06692516 |
# |    clip_fraction        | 0.445      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.08      |
# |    explained_variance   | 0.869      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.598      |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.00191   |
# |    std                  | 0.683      |
# |    value_loss           | 3.33       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 43          |
# |    time_elapsed         | 1268        |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.077704184 |
# |    clip_fraction        | 0.475       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.09       |
# |    explained_variance   | 0.909       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.678       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00359    |
# |    std                  | 0.686       |
# |    value_loss           | 7.29        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 44         |
# |    time_elapsed         | 1299       |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.11956608 |
# |    clip_fraction        | 0.512      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.09      |
# |    explained_variance   | 0.932      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.529      |
# |    n_updates            | 430        |
# |    policy_gradient_loss | 0.0164     |
# |    std                  | 0.684      |
# |    value_loss           | 7.12       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 45         |
# |    time_elapsed         | 1329       |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.14823279 |
# |    clip_fraction        | 0.544      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.08      |
# |    explained_variance   | 0.918      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.513      |
# |    n_updates            | 440        |
# |    policy_gradient_loss | 0.00304    |
# |    std                  | 0.682      |
# |    value_loss           | 9.8        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 46         |
# |    time_elapsed         | 1358       |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.10394508 |
# |    clip_fraction        | 0.548      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.08      |
# |    explained_variance   | 0.865      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.63       |
# |    n_updates            | 450        |
# |    policy_gradient_loss | 0.0163     |
# |    std                  | 0.684      |
# |    value_loss           | 9.32       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 47         |
# |    time_elapsed         | 1388       |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.10331336 |
# |    clip_fraction        | 0.485      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.08      |
# |    explained_variance   | 0.959      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.12       |
# |    n_updates            | 460        |
# |    policy_gradient_loss | 0.015      |
# |    std                  | 0.682      |
# |    value_loss           | 8.05       |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 69        |
# |    iterations           | 48        |
# |    time_elapsed         | 1418      |
# |    total_timesteps      | 98304     |
# | train/                  |           |
# |    approx_kl            | 0.1014628 |
# |    clip_fraction        | 0.479     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.07     |
# |    explained_variance   | 0.959     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.83      |
# |    n_updates            | 470       |
# |    policy_gradient_loss | 0.00649   |
# |    std                  | 0.681     |
# |    value_loss           | 9.55      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 49         |
# |    time_elapsed         | 1448       |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.11442608 |
# |    clip_fraction        | 0.529      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.08      |
# |    explained_variance   | 0.879      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.45       |
# |    n_updates            | 480        |
# |    policy_gradient_loss | 0.0221     |
# |    std                  | 0.684      |
# |    value_loss           | 11.3       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 50         |
# |    time_elapsed         | 1478       |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.16565399 |
# |    clip_fraction        | 0.52       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.08      |
# |    explained_variance   | 0.94       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.89       |
# |    n_updates            | 490        |
# |    policy_gradient_loss | 0.0219     |
# |    std                  | 0.683      |
# |    value_loss           | 19.9       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 51         |
# |    time_elapsed         | 1507       |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.18307216 |
# |    clip_fraction        | 0.541      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.09      |
# |    explained_variance   | 0.916      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.74       |
# |    n_updates            | 500        |
# |    policy_gradient_loss | 0.0248     |
# |    std                  | 0.687      |
# |    value_loss           | 26.7       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 52         |
# |    time_elapsed         | 1537       |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.21140537 |
# |    clip_fraction        | 0.602      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.1       |
# |    explained_variance   | 0.903      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.74       |
# |    n_updates            | 510        |
# |    policy_gradient_loss | 0.0496     |
# |    std                  | 0.69       |
# |    value_loss           | 21.3       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 53         |
# |    time_elapsed         | 1568       |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.20595062 |
# |    clip_fraction        | 0.605      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.11      |
# |    explained_variance   | 0.92       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.68       |
# |    n_updates            | 520        |
# |    policy_gradient_loss | 0.0215     |
# |    std                  | 0.692      |
# |    value_loss           | 17         |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 54         |
# |    time_elapsed         | 1598       |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.24697782 |
# |    clip_fraction        | 0.62       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.12      |
# |    explained_variance   | 0.906      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.43       |
# |    n_updates            | 530        |
# |    policy_gradient_loss | 0.0206     |
# |    std                  | 0.693      |
# |    value_loss           | 12         |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 55         |
# |    time_elapsed         | 1627       |
# |    total_timesteps      | 112640     |
# | train/                  |            |
# |    approx_kl            | 0.15322328 |
# |    clip_fraction        | 0.559      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.13      |
# |    explained_variance   | 0.955      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.18       |
# |    n_updates            | 540        |
# |    policy_gradient_loss | 0.0131     |
# |    std                  | 0.695      |
# |    value_loss           | 9.01       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 56         |
# |    time_elapsed         | 1658       |
# |    total_timesteps      | 114688     |
# | train/                  |            |
# |    approx_kl            | 0.20934775 |
# |    clip_fraction        | 0.586      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.13      |
# |    explained_variance   | 0.912      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.306      |
# |    n_updates            | 550        |
# |    policy_gradient_loss | 0.0231     |
# |    std                  | 0.694      |
# |    value_loss           | 6.14       |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 69        |
# |    iterations           | 57        |
# |    time_elapsed         | 1688      |
# |    total_timesteps      | 116736    |
# | train/                  |           |
# |    approx_kl            | 0.1183451 |
# |    clip_fraction        | 0.555     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.13     |
# |    explained_variance   | 0.879     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.59      |
# |    n_updates            | 560       |
# |    policy_gradient_loss | 0.021     |
# |    std                  | 0.695     |
# |    value_loss           | 9.63      |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 69          |
# |    iterations           | 58          |
# |    time_elapsed         | 1717        |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.102018565 |
# |    clip_fraction        | 0.536       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.15       |
# |    explained_variance   | 0.903       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.34        |
# |    n_updates            | 570         |
# |    policy_gradient_loss | 0.0112      |
# |    std                  | 0.7         |
# |    value_loss           | 9.66        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 59         |
# |    time_elapsed         | 1747       |
# |    total_timesteps      | 120832     |
# | train/                  |            |
# |    approx_kl            | 0.15664788 |
# |    clip_fraction        | 0.55       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.16      |
# |    explained_variance   | 0.903      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.18       |
# |    n_updates            | 580        |
# |    policy_gradient_loss | 0.012      |
# |    std                  | 0.701      |
# |    value_loss           | 11.1       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 60         |
# |    time_elapsed         | 1777       |
# |    total_timesteps      | 122880     |
# | train/                  |            |
# |    approx_kl            | 0.15799537 |
# |    clip_fraction        | 0.58       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.19      |
# |    explained_variance   | 0.914      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.405      |
# |    n_updates            | 590        |
# |    policy_gradient_loss | 0.0166     |
# |    std                  | 0.713      |
# |    value_loss           | 5.65       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 61         |
# |    time_elapsed         | 1807       |
# |    total_timesteps      | 124928     |
# | train/                  |            |
# |    approx_kl            | 0.10777567 |
# |    clip_fraction        | 0.567      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.21      |
# |    explained_variance   | 0.878      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.94       |
# |    n_updates            | 600        |
# |    policy_gradient_loss | 0.0221     |
# |    std                  | 0.712      |
# |    value_loss           | 17.8       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 62         |
# |    time_elapsed         | 1837       |
# |    total_timesteps      | 126976     |
# | train/                  |            |
# |    approx_kl            | 0.19626012 |
# |    clip_fraction        | 0.606      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.22      |
# |    explained_variance   | 0.867      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.07       |
# ...
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.55      |
# |    explained_variance   | 0.958      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.859      |
# |    n_updates            | 2240       |
# |    policy_gradient_loss | 0.0169     |
# |    std                  | 0.79       |
# |    value_loss           | 7.03       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 226        |
# |    time_elapsed         | 6776       |
# |    total_timesteps      | 462848     |
# | train/                  |            |
# |    approx_kl            | 0.09325227 |
# |    clip_fraction        | 0.363      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.56      |
# |    explained_variance   | 0.985      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.294      |
# |    n_updates            | 2250       |
# |    policy_gradient_loss | 0.00305    |
# |    std                  | 0.791      |
# |    value_loss           | 2.01       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 227        |
# |    time_elapsed         | 6807       |
# |    total_timesteps      | 464896     |
# | train/                  |            |
# |    approx_kl            | 0.12488642 |
# |    clip_fraction        | 0.425      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.55      |
# |    explained_variance   | 0.954      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.64       |
# |    n_updates            | 2260       |
# |    policy_gradient_loss | 0.015      |
# |    std                  | 0.791      |
# |    value_loss           | 12.5       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 228        |
# |    time_elapsed         | 6837       |
# |    total_timesteps      | 466944     |
# | train/                  |            |
# |    approx_kl            | 0.30774733 |
# |    clip_fraction        | 0.475      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.55      |
# |    explained_variance   | 0.977      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.306      |
# |    n_updates            | 2270       |
# |    policy_gradient_loss | 0.00978    |
# |    std                  | 0.788      |
# |    value_loss           | 2.97       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 229        |
# |    time_elapsed         | 6867       |
# |    total_timesteps      | 468992     |
# | train/                  |            |
# |    approx_kl            | 0.11504258 |
# |    clip_fraction        | 0.306      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.54      |
# |    explained_variance   | 0.986      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.281      |
# |    n_updates            | 2280       |
# |    policy_gradient_loss | 0.0148     |
# |    std                  | 0.79       |
# |    value_loss           | 2.47       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 230        |
# |    time_elapsed         | 6897       |
# |    total_timesteps      | 471040     |
# | train/                  |            |
# |    approx_kl            | 0.14482959 |
# |    clip_fraction        | 0.29       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.56      |
# |    explained_variance   | 0.991      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.129      |
# |    n_updates            | 2290       |
# |    policy_gradient_loss | -0.000687  |
# |    std                  | 0.794      |
# |    value_loss           | 1.37       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 231        |
# |    time_elapsed         | 6926       |
# |    total_timesteps      | 473088     |
# | train/                  |            |
# |    approx_kl            | 0.10445765 |
# |    clip_fraction        | 0.328      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.55      |
# |    explained_variance   | 0.977      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.511      |
# |    n_updates            | 2300       |
# |    policy_gradient_loss | 0.0124     |
# |    std                  | 0.784      |
# |    value_loss           | 3.72       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 232         |
# |    time_elapsed         | 6957        |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.098661765 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.53       |
# |    explained_variance   | 0.98        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.059       |
# |    n_updates            | 2310        |
# |    policy_gradient_loss | 0.00501     |
# |    std                  | 0.786       |
# |    value_loss           | 2.21        |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 68        |
# |    iterations           | 233       |
# |    time_elapsed         | 6988      |
# |    total_timesteps      | 477184    |
# | train/                  |           |
# |    approx_kl            | 0.1384953 |
# |    clip_fraction        | 0.394     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.54     |
# |    explained_variance   | 0.956     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.574     |
# |    n_updates            | 2320      |
# |    policy_gradient_loss | 0.0547    |
# |    std                  | 0.789     |
# |    value_loss           | 7.55      |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 68          |
# |    iterations           | 234         |
# |    time_elapsed         | 7018        |
# |    total_timesteps      | 479232      |
# | train/                  |             |
# |    approx_kl            | 0.094076455 |
# |    clip_fraction        | 0.509       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.55       |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.612       |
# |    n_updates            | 2330        |
# |    policy_gradient_loss | 0.0212      |
# |    std                  | 0.793       |
# |    value_loss           | 6.2         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 235        |
# |    time_elapsed         | 7048       |
# |    total_timesteps      | 481280     |
# | train/                  |            |
# |    approx_kl            | 0.09714836 |
# |    clip_fraction        | 0.264      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.57      |
# |    explained_variance   | 0.979      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.181      |
# |    n_updates            | 2340       |
# |    policy_gradient_loss | -0.00175   |
# |    std                  | 0.795      |
# |    value_loss           | 3.3        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 236        |
# |    time_elapsed         | 7079       |
# |    total_timesteps      | 483328     |
# | train/                  |            |
# |    approx_kl            | 0.16418059 |
# |    clip_fraction        | 0.511      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.57      |
# |    explained_variance   | 0.956      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.475      |
# |    n_updates            | 2350       |
# |    policy_gradient_loss | 0.0103     |
# |    std                  | 0.797      |
# |    value_loss           | 5.09       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 237        |
# |    time_elapsed         | 7109       |
# |    total_timesteps      | 485376     |
# | train/                  |            |
# |    approx_kl            | 0.11515033 |
# |    clip_fraction        | 0.346      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.56      |
# |    explained_variance   | 0.959      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.513      |
# |    n_updates            | 2360       |
# |    policy_gradient_loss | 0.0223     |
# |    std                  | 0.787      |
# |    value_loss           | 3.24       |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 68        |
# |    iterations           | 238       |
# |    time_elapsed         | 7138      |
# |    total_timesteps      | 487424    |
# | train/                  |           |
# |    approx_kl            | 0.1480307 |
# |    clip_fraction        | 0.343     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.55     |
# |    explained_variance   | 0.964     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.924     |
# |    n_updates            | 2370      |
# |    policy_gradient_loss | 0.0122    |
# |    std                  | 0.79      |
# |    value_loss           | 7.75      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 239        |
# |    time_elapsed         | 7168       |
# |    total_timesteps      | 489472     |
# | train/                  |            |
# |    approx_kl            | 0.13042888 |
# |    clip_fraction        | 0.301      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.55      |
# |    explained_variance   | 0.985      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.351      |
# |    n_updates            | 2380       |
# |    policy_gradient_loss | 0.0201     |
# |    std                  | 0.792      |
# |    value_loss           | 1.92       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 240        |
# |    time_elapsed         | 7197       |
# |    total_timesteps      | 491520     |
# | train/                  |            |
# |    approx_kl            | 0.12950948 |
# |    clip_fraction        | 0.306      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.55      |
# |    explained_variance   | 0.982      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.338      |
# |    n_updates            | 2390       |
# |    policy_gradient_loss | -0.00151   |
# |    std                  | 0.79       |
# |    value_loss           | 1.84       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 241        |
# |    time_elapsed         | 7227       |
# |    total_timesteps      | 493568     |
# | train/                  |            |
# |    approx_kl            | 0.43872768 |
# |    clip_fraction        | 0.308      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.53      |
# |    explained_variance   | 0.943      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.149      |
# |    n_updates            | 2400       |
# |    policy_gradient_loss | -0.00553   |
# |    std                  | 0.779      |
# |    value_loss           | 1.38       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 242        |
# |    time_elapsed         | 7257       |
# |    total_timesteps      | 495616     |
# | train/                  |            |
# |    approx_kl            | 0.23439057 |
# |    clip_fraction        | 0.315      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.5       |
# |    explained_variance   | 0.952      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0149     |
# |    n_updates            | 2410       |
# |    policy_gradient_loss | -0.00697   |
# |    std                  | 0.771      |
# |    value_loss           | 0.846      |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 68        |
# |    iterations           | 243       |
# |    time_elapsed         | 7287      |
# |    total_timesteps      | 497664    |
# | train/                  |           |
# |    approx_kl            | 0.0859082 |
# |    clip_fraction        | 0.247     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.48     |
# |    explained_variance   | 0.92      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0909    |
# |    n_updates            | 2420      |
# |    policy_gradient_loss | 0.00182   |
# |    std                  | 0.771     |
# |    value_loss           | 2.69      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 244        |
# |    time_elapsed         | 7317       |
# |    total_timesteps      | 499712     |
# | train/                  |            |
# |    approx_kl            | 0.23587127 |
# |    clip_fraction        | 0.252      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.48      |
# |    explained_variance   | 0.923      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0255     |
# |    n_updates            | 2430       |
# |    policy_gradient_loss | 0.00409    |
# |    std                  | 0.769      |
# |    value_loss           | 0.638      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 68         |
# |    iterations           | 245        |
# |    time_elapsed         | 7348       |
# |    total_timesteps      | 501760     |
# | train/                  |            |
# |    approx_kl            | 0.14696117 |
# |    clip_fraction        | 0.225      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.45      |
# |    explained_variance   | 0.935      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0157     |
# |    n_updates            | 2440       |
# |    policy_gradient_loss | -0.0149    |
# |    std                  | 0.752      |
# |    value_loss           | 0.315      |
# ----------------------------------------

# %%
model_path = os.path.join('models')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
model.save(model_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
